# %%
from sqlalchemy import Table, MetaData, create_engine, select
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
engine = create_engine('mysql+pymysql://root:Jam3sHard3n13@localhost:3306/sakila')

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c3cc7c016905> in <module>
# ----> 1 engine['']
#
# TypeError: 'Engine' object is not subscriptable

# %%
# Query without SQL Alchemy pythonic language
stmt = 'SELECT * FROM film_category'
results_film_category = connection.execute(stmt).fetchall()

# %%
results_film_category[1].keys()
# Out:
# ['film_id', 'category_id', 'last_update']

# %%
results_film_category[0].keys()
# Out:
# ['film_id', 'category_id', 'last_update']

# %%
stmt = 'SELECT * FROM category'
results_category = connection.execute(stmt).fetchall()

# %%
results_category[0].keys()
# Out:
# ['category_id', 'name', 'last_update']

# %%
results_category[:5]
# Out:
# [(1, 'Action', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (2, 'Animation', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (3, 'Children', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (4, 'Classics', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (5, 'Comedy', datetime.datetime(2006, 2, 15, 4, 46, 27))]

# %%
results_category
# Out:
# [(1, 'Action', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (2, 'Animation', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (3, 'Children', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (4, 'Classics', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (5, 'Comedy', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (6, 'Documentary', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (7, 'Drama', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (8, 'Family', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (9, 'Foreign', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (10, 'Games', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (11, 'Horror', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (12, 'Music', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (13, 'New', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (14, 'Sci-Fi', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (15, 'Sports', datetime.datetime(2006, 2, 15, 4, 46, 27)),
#  (16, 'Travel', datetime.datetime(2006, 2, 15, 4, 46, 27))]

# %%
# Pulling together film and category ID
# Query ask for Title, Length (runtime), and film category
# Goal was to compare runtime and film category. In 'film database', category is coded. Needed to use codes in category_id to
#compare properly. Had to bring in film_category database to connect category id to film.
stmt = """SELECT film.title, film.length, category.name AS Category FROM film 
        JOIN film_category ON film.film_id = film_category.film_id
        JOIN category on film_category.category_id = category.category_id
        ;
"""
results_join = connection.execute(stmt).fetchall()

# %%
len(results_join)
# Out:
# 1000

# %%
df = pd.DataFrame(results_join)
df.columns = results_join[0].keys()

# %%
# Average runtime for each category
df.groupby('Category')['length'].apply(np.mean).sort_values(ascending = False)
# Out:
# Category
# Sports         128.202703
# Games          127.836066
# Foreign        121.698630
# Drama          120.838710
# Comedy         115.827586
# Family         114.782609
# Music          113.647059
# Travel         113.315789
# Horror         112.482143
# Classics       111.666667
# Action         111.609375
# New            111.126984
# Animation      111.015152
# Children       109.800000
# Documentary    108.750000
# Sci-Fi         108.196721
# Name: length, dtype: float64

# %%
# Select film title, film length, category, rating, release year. Will require joining on multiple tables 
query = """SELECT film.title, film.release_year AS Year, film.length AS RunTime, film.rating, category.name AS Category 
            FROM film
            JOIN film_category ON film.film_id = film_category.film_id
            JOIN category ON film_category.category_id = category.category_id  
            ;"""

# %%
results_query = connection.execute(query).fetchall()

# %%
results_query[:5]
# Out:
# [('AMADEUS HOLY', 2006, 113, 'PG', 'Action'),
#  ('AMERICAN CIRCUS', 2006, 129, 'R', 'Action'),
#  ('ANTITRUST TOMATOES', 2006, 168, 'NC-17', 'Action'),
#  ('ARK RIDGEMONT', 2006, 68, 'NC-17', 'Action'),
#  ('BAREFOOT MANCHURIAN', 2006, 129, 'G', 'Action')]

# %%
df = pd.DataFrame(results_query)
df.columns = results_query[0].keys()

# %%
df.head()
# Out:
#                  title  Year  RunTime rating Category
# 0         AMADEUS HOLY  2006      113     PG   Action
# 1      AMERICAN CIRCUS  2006      129      R   Action
# 2   ANTITRUST TOMATOES  2006      168  NC-17   Action
# 3        ARK RIDGEMONT  2006       68  NC-17   Action
# 4  BAREFOOT MANCHURIAN  2006      129      G   Action

# %%
df.groupby('rating')['RunTime'].apply(np.mean)
# Out:
# rating
# G        111.050562
# NC-17    113.228571
# PG       112.005155
# PG-13    120.443946
# R        118.661538
# Name: RunTime, dtype: float64

# %%
connection.execute('Select * FROM film_list').first()
# Out:
# C:\Users\Nate P\Anaconda3\envs\nbasalaryproject\lib\site-packages\pymysql\cursors.py:170: Warning: (1287, "'utf8mb3' is deprecated and will be removed in a future release. Please use utf8mb4 instead")
#   result = self._query(query)
# (1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 'Documentary', Decimal('0.99'), 86, 'PG', 'OPRAH KILMER, ROCK DUKAKIS, MARY KEITEL, PENELOPE GUINESS, CHRISTIAN GABLE, LUCILLE TRACY, SANDRA PECK, JOHNNY CAGE, MENA TEMPLE, WARREN NOLTE')

# %%
connection.execute('Select * FROM actor').first().keys()
# Out:
# ['actor_id', 'first_name', 'last_name', 'last_update']

# %%
connection.execute('Select * FROM film_actor').fetchall()[0].keys()
# Out:
# ['actor_id', 'film_id', 'last_update']

# %%
# Connect actor_id with film_actor, then count number of actors
connection.execute(""" SELECT actor.first_name, actor.last_name, film.title FROM actor
                        JOIN film_actor ON actor.actor_id = film_actor.actor_id
                        JOIN film ON film.film_id = film_actor.film_id
                        ;""").fetchall()
## Success! Next step: Combine First and last name into one column to count appearances by each actor
# Out:
# [('PENELOPE', 'GUINESS', 'ACADEMY DINOSAUR'),
#  ('PENELOPE', 'GUINESS', 'ANACONDA CONFESSIONS'),
#  ('PENELOPE', 'GUINESS', 'ANGELS LIFE'),
#  ('PENELOPE', 'GUINESS', 'BULWORTH COMMANDMENTS'),
#  ('PENELOPE', 'GUINESS', 'CHEAPER CLYDE'),
#  ('PENELOPE', 'GUINESS', 'COLOR PHILADELPHIA'),
#  ('PENELOPE', 'GUINESS', 'ELEPHANT TROJAN'),
#  ('PENELOPE', 'GUINESS', 'GLEAMING JAWBREAKER'),
#  ('PENELOPE', 'GUINESS', 'HUMAN GRAFFITI'),
#  ('PENELOPE', 'GUINESS', 'KING EVOLUTION'),
#  ('PENELOPE', 'GUINESS', 'LADY STAGE'),
#  ('PENELOPE', 'GUINESS', 'LANGUAGE COWBOY'),
#  ('PENELOPE', 'GUINESS', 'MULHOLLAND BEAST'),
#  ('PENELOPE', 'GUINESS', 'OKLAHOMA JUMANJI'),
#  ('PENELOPE', 'GUINESS', 'RULES HUMAN'),
#  ('PENELOPE', 'GUINESS', 'SPLASH GUMP'),
#  ('PENELOPE', 'GUINESS', 'VERTIGO NORTHWEST'),
#  ('PENELOPE', 'GUINESS', 'WESTWARD SEABISCUIT'),
#  ('PENELOPE', 'GUINESS', 'WIZARD COLDBLOODED'),
#  ('NICK', 'WAHLBERG', 'ADAPTATION HOLES'),
#  ('NICK', 'WAHLBERG', 'APACHE DIVINE'),
# ...

# %%
results_selection = connection.execute(""" SELECT CONCAT(actor.first_name, ' ', actor.last_name), film.title FROM actor
                        JOIN film_actor ON actor.actor_id = film_actor.actor_id
                        JOIN film ON film.film_id = film_actor.film_id
                        ;""").fetchall()
len(results_selection)
# Out:
# 5462

# %%
df = pd.DataFrame(results_selection)
df.columns = results_selection[0].keys()
df.rename(columns = {df.columns[0]:'Actor Name', 'title':'Title'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Actor Name', 'Title'], dtype='object')

# %%
len(df)
# Out:
# 5462

# %%
len(results_selection)
# Out:
# 5462

# %%
df['Actor Name'].unique()
# Out:
# array(['PENELOPE GUINESS', 'NICK WAHLBERG', 'ED CHASE', 'JENNIFER DAVIS',
#        'JOHNNY LOLLOBRIGIDA', 'BETTE NICHOLSON', 'GRACE MOSTEL',
#        'MATTHEW JOHANSSON', 'JOE SWANK', 'CHRISTIAN GABLE', 'ZERO CAGE',
#        'KARL BERRY', 'UMA WOOD', 'VIVIEN BERGEN', 'CUBA OLIVIER',
#        'FRED COSTNER', 'HELEN VOIGHT', 'DAN TORN', 'BOB FAWCETT',
#        'LUCILLE TRACY', 'KIRSTEN PALTROW', 'ELVIS MARX', 'SANDRA KILMER',
#        'CAMERON STREEP', 'KEVIN BLOOM', 'RIP CRAWFORD', 'JULIA MCQUEEN',
#        'WOODY HOFFMAN', 'ALEC WAYNE', 'SANDRA PECK', 'SISSY SOBIESKI',
#        'TIM HACKMAN', 'MILLA PECK', 'AUDREY OLIVIER', 'JUDY DEAN',
#        'BURT DUKAKIS', 'VAL BOLGER', 'TOM MCKELLEN', 'GOLDIE BRODY',
#        'JOHNNY CAGE', 'JODIE DEGENERES', 'TOM MIRANDA', 'KIRK JOVOVICH',
#        'NICK STALLONE', 'REESE KILMER', 'PARKER GOLDBERG',
#        'JULIA BARRYMORE', 'FRANCES DAY-LEWIS', 'ANNE CRONYN',
#        'NATALIE HOPKINS', 'GARY PHOENIX', 'CARMEN HUNT', 'MENA TEMPLE',
# ...

# %%
df['Actor Name'].count()
# Out:
# 5462

# %%
df.groupby('Actor Name').count().sort_values(by = 'Title', ascending = False)
# Out:
#                  Title
# Actor Name
# SUSAN DAVIS         54
# GINA DEGENERES      42
# WALTER TORN         41
# MARY KEITEL         40
# MATTHEW CARREY      39
# ...                ...
# SISSY SOBIESKI      18
# JULIA ZELLWEGER     16
# JULIA FAWCETT       15
# JUDY DEAN           15
# EMILY DEE           14
#
# [199 rows x 1 columns]

# %%
connection.execute(""" SELECT CONCAT(actor.first_name, ' ', actor.last_name) AS Actor_Name, count(film.title) FROM actor
                        JOIN film_actor ON actor.actor_id = film_actor.actor_id
                        JOIN film ON film.film_id = film_actor.film_id
                        GROUP BY Actor_Name
                        ORDER BY count(film.title) DESC
                        ;""").fetchall()
# Above is SQL syntax for joining multiple tables at once, then grouping by Actor Name. Order by film.title.
# Out:
# [('SUSAN DAVIS', 54),
#  ('GINA DEGENERES', 42),
#  ('WALTER TORN', 41),
#  ('MARY KEITEL', 40),
#  ('MATTHEW CARREY', 39),
#  ('SANDRA KILMER', 37),
#  ('SCARLETT DAMON', 36),
#  ('UMA WOOD', 35),
#  ('VAL BOLGER', 35),
#  ('HENRY BERRY', 35),
#  ('GROUCHO DUNST', 35),
#  ('ANGELA WITHERSPOON', 35),
#  ('VIVIEN BASINGER', 35),
#  ('ANGELA HUDSON', 34),
#  ('KIRSTEN AKROYD', 34),
#  ('SIDNEY CROWE', 34),
#  ('WARREN NOLTE', 34),
#  ('JAYNE NOLTE', 34),
#  ('RIP CRAWFORD', 33),
#  ('JULIA MCQUEEN', 33),
#  ('BEN WILLIS', 33),
#  ('SEAN GUINESS', 33),
#  ('KENNETH TORN', 33),
#  ('CAMERON ZELLWEGER', 33),
#  ('RENEE TRACY', 33),
#  ('KEVIN GARLAND', 33),
#  ('EWAN GOODING', 33),
#  ('ALBERT JOHANSSON', 33),
#  ('RENEE BALL', 33),
#  ('REESE WEST', 33),
#  ('HELEN VOIGHT', 32),
#  ('REESE KILMER', 32),
#  ('NATALIE HOPKINS', 32),
#  ('CHRISTIAN AKROYD', 32),
#  ('WARREN JACKMAN', 32),
#  ('JULIANNE DENCH', 32),
#  ('ED MANSFIELD', 32),
#  ('WHOOPI HURT', 32),
#  ('GRETA MALDEN', 32),
# ...
